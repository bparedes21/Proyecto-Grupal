# %%
# Importamos librerías necesarias
import pandas as pd
import numpy as np
import os
import glob

# %%
from funcionesETL import *

# %%
csv_files = glob.glob('*.csv')
lista_data_csv = []
  
# Creamos un bucle que recorre cada archivo csv de la carpeta, crea un df y lo agrega a una lista
for filename in csv_files:
    data = pd.read_csv(filename, encoding='cp1252')
    lista_data_csv.append(data)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_15860\755577993.py:6: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(filename, encoding='cp1252')

# %%
# Separamos de la lista el df que contiene el diccionario de variables
DataDictionary = lista_data_csv.pop(4)

# %%
# Diccionario que contiene cada df y le asigna como key el nombre del archivo correspondiente
dicc_df = {'cities_crosswalk':lista_data_csv[0], 'City_time_series':lista_data_csv[1],
           'CountyCrossWalk_Zillow':lista_data_csv[2],'County_time_series':lista_data_csv[3],
           'Metro_time_series':lista_data_csv[4],'Neighborhood_time_series':lista_data_csv[5],
           'State_time_series':lista_data_csv[6],'Zip_time_series':lista_data_csv[7]}

# %% [markdown]
# ## - Valores Nulos

# %%
correccion_VF(dicc_df)

# %%
# Verificación
for key in dicc_df:
    col = dicc_df[key].columns
    print(key,'\n')
    for e in col:
        print(e,'\t',round(len(dicc_df[key][e][dicc_df[key][e].isnull()])/len(dicc_df[key])*100,2),'%')
    print('\n\n')
# Out:
# cities_crosswalk
#
# Unique_City_ID 	 0.0 %
# City 	 0.0 %
# County 	 0.0 %
# State 	 0.0 %
#
#
#
# City_time_series
#
# Date 	 0.0 %
# RegionName 	 0.0 %
# ZHVIPerSqft_AllHomes 	 0.0 %
# PctOfHomesDecreasingInValues_AllHomes 	 0.0 %
# PctOfHomesIncreasingInValues_AllHomes 	 0.0 %
# ZHVI_2bedroom 	 0.0 %
# ZHVI_3bedroom 	 0.0 %
# ZHVI_4bedroom 	 0.0 %
# ZHVI_AllHomes 	 0.0 %
# ZHVI_BottomTier 	 0.0 %
# ZHVI_MiddleTier 	 0.0 %
# ZHVI_SingleFamilyResidence 	 0.0 %
# ZHVI_TopTier 	 0.0 %
#
#
#
# CountyCrossWalk_Zillow
#
# ï»¿CountyName 	 0.0 %
# StateName 	 0.0 %
# StateFIPS 	 0.0 %
# CountyFIPS 	 0.0 %
# MetroName_Zillow 	 0.0 %
# CBSAName 	 0.0 %
# CountyRegionID_Zillow 	 0.0 %
# MetroRegionID_Zillow 	 0.0 %
# FIPS 	 0.0 %
# CBSACode 	 0.0 %
#
#
#
# County_time_series
#
# Date 	 0.0 %
# RegionName 	 0.0 %
# InventorySeasonallyAdjusted_AllHomes 	 0.0 %
# InventoryRaw_AllHomes 	 0.0 %
# MedianListingPricePerSqft_AllHomes 	 0.0 %
# MedianListingPricePerSqft_SingleFamilyResidence 	 0.0 %
# MedianListingPrice_AllHomes 	 0.0 %
# MedianListingPrice_SingleFamilyResidence 	 0.0 %
# ZHVIPerSqft_AllHomes 	 0.0 %
# PctOfHomesDecreasingInValues_AllHomes 	 0.0 %
# PctOfHomesIncreasingInValues_AllHomes 	 0.0 %
# ZHVI_1bedroom 	 0.0 %
# ZHVI_2bedroom 	 0.0 %
# ZHVI_3bedroom 	 0.0 %
# ZHVI_4bedroom 	 0.0 %
# ZHVI_5BedroomOrMore 	 0.0 %
# ZHVI_AllHomes 	 0.0 %
# ZHVI_BottomTier 	 0.0 %
# ZHVI_CondoCoop 	 0.0 %
# ZHVI_MiddleTier 	 0.0 %
# ZHVI_SingleFamilyResidence 	 0.0 %
# ZHVI_TopTier 	 0.0 %
#
#
#
# Metro_time_series
#
# Date 	 0.0 %
# RegionName 	 0.0 %
# InventorySeasonallyAdjusted_AllHomes 	 0.0 %
# InventoryRaw_AllHomes 	 0.0 %
# MedianListingPricePerSqft_AllHomes 	 0.0 %
# MedianListingPricePerSqft_SingleFamilyResidence 	 0.0 %
# MedianListingPrice_AllHomes 	 0.0 %
# MedianListingPrice_SingleFamilyResidence 	 0.0 %
# ZHVIPerSqft_AllHomes 	 0.0 %
# PctOfListingsWithPriceReductionsSeasAdj_AllHomes 	 0.0 %
# PctOfListingsWithPriceReductions_AllHomes 	 0.0 %
# ZHVI_1bedroom 	 0.0 %
# ZHVI_2bedroom 	 0.0 %
# ZHVI_3bedroom 	 0.0 %
# ZHVI_4bedroom 	 0.0 %
# ZHVI_5BedroomOrMore 	 0.0 %
# ZHVI_AllHomes 	 0.0 %
# ZHVI_BottomTier 	 0.0 %
# ZHVI_CondoCoop 	 0.0 %
# ZHVI_MiddleTier 	 0.0 %
# ZHVI_SingleFamilyResidence 	 0.0 %
# ZHVI_TopTier 	 0.0 %
#
#
#
# Neighborhood_time_series
#
# Date 	 0.0 %
# RegionName 	 0.0 %
# ZHVIPerSqft_AllHomes 	 0.0 %
# PctOfHomesDecreasingInValues_AllHomes 	 0.0 %
# PctOfHomesIncreasingInValues_AllHomes 	 0.0 %
# ZHVI_2bedroom 	 0.0 %
# ZHVI_3bedroom 	 0.0 %
# ZHVI_4bedroom 	 0.0 %
# ZHVI_AllHomes 	 0.0 %
# ZHVI_BottomTier 	 0.0 %
# ZHVI_MiddleTier 	 0.0 %
# ZHVI_SingleFamilyResidence 	 0.0 %
# ZHVI_TopTier 	 0.0 %
# ZRI_AllHomes 	 0.0 %
# ZRI_AllHomesPlusMultifamily 	 0.0 %
# ZriPerSqft_AllHomes 	 0.0 %
# Zri_SingleFamilyResidenceRental 	 0.0 %
#
#
#
# State_time_series
#
# Date 	 0.0 %
# RegionName 	 0.0 %
# DaysOnZillow_AllHomes 	 0.0 %
# InventorySeasonallyAdjusted_AllHomes 	 0.0 %
# InventoryRaw_AllHomes 	 0.0 %
# MedianListingPricePerSqft_2Bedroom 	 0.0 %
# MedianListingPricePerSqft_3Bedroom 	 0.0 %
# MedianListingPricePerSqft_4Bedroom 	 0.0 %
# MedianListingPricePerSqft_5BedroomOrMore 	 0.0 %
# MedianListingPricePerSqft_AllHomes 	 0.0 %
# MedianListingPricePerSqft_CondoCoop 	 0.0 %
# MedianListingPricePerSqft_SingleFamilyResidence 	 0.0 %
# MedianListingPrice_2Bedroom 	 0.0 %
# MedianListingPrice_3Bedroom 	 0.0 %
# MedianListingPrice_4Bedroom 	 0.0 %
# MedianListingPrice_5BedroomOrMore 	 0.0 %
# MedianListingPrice_AllHomes 	 0.0 %
# MedianListingPrice_SingleFamilyResidence 	 0.0 %
# MedianPctOfPriceReduction_AllHomes 	 0.0 %
# MedianPctOfPriceReduction_SingleFamilyResidence 	 0.0 %
# MedianPriceCutDollar_AllHomes 	 0.0 %
# MedianPriceCutDollar_SingleFamilyResidence 	 0.0 %
# MedianRentalPricePerSqft_2Bedroom 	 0.0 %
# MedianRentalPricePerSqft_3Bedroom 	 0.0 %
# MedianRentalPricePerSqft_AllHomes 	 0.0 %
# MedianRentalPricePerSqft_MultiFamilyResidence5PlusUnits 	 0.0 %
# MedianRentalPricePerSqft_SingleFamilyResidence 	 0.0 %
# MedianRentalPrice_2Bedroom 	 0.0 %
# MedianRentalPrice_3Bedroom 	 0.0 %
# MedianRentalPrice_AllHomes 	 0.0 %
# MedianRentalPrice_MultiFamilyResidence5PlusUnits 	 0.0 %
# MedianRentalPrice_SingleFamilyResidence 	 0.0 %
# ZHVIPerSqft_AllHomes 	 0.0 %
# PctOfHomesDecreasingInValues_AllHomes 	 0.0 %
# PctOfHomesIncreasingInValues_AllHomes 	 0.0 %
# PctOfListingsWithPriceReductionsSeasAdj_AllHomes 	 0.0 %
# PctOfListingsWithPriceReductionsSeasAdj_CondoCoop 	 0.0 %
# PctOfListingsWithPriceReductionsSeasAdj_SingleFamilyResidence 	 0.0 %
# PctOfListingsWithPriceReductions_AllHomes 	 0.0 %
# PctOfListingsWithPriceReductions_CondoCoop 	 0.0 %
# PctOfListingsWithPriceReductions_SingleFamilyResidence 	 0.0 %
# PriceToRentRatio_AllHomes 	 0.0 %
# Sale_Counts 	 0.0 %
# Sale_Counts_Seas_Adj 	 0.0 %
# Sale_Prices 	 0.0 %
# ZHVI_1bedroom 	 0.0 %
# ZHVI_2bedroom 	 0.0 %
# ZHVI_3bedroom 	 0.0 %
# ZHVI_4bedroom 	 0.0 %
# ZHVI_5BedroomOrMore 	 0.0 %
# ZHVI_AllHomes 	 0.0 %
# ZHVI_BottomTier 	 0.0 %
# ZHVI_CondoCoop 	 0.0 %
# ZHVI_MiddleTier 	 0.0 %
# ZHVI_SingleFamilyResidence 	 0.0 %
# ZHVI_TopTier 	 0.0 %
# ZRI_AllHomes 	 0.0 %
# ZRI_AllHomesPlusMultifamily 	 0.0 %
# ZriPerSqft_AllHomes 	 0.0 %
# Zri_MultiFamilyResidenceRental 	 0.0 %
# Zri_SingleFamilyResidenceRental 	 0.0 %
#
#
#
# Zip_time_series
#
# Date 	 0.0 %
# RegionName 	 0.0 %
# ZHVIPerSqft_AllHomes 	 0.0 %
# PctOfHomesDecreasingInValues_AllHomes 	 0.0 %
# PctOfHomesIncreasingInValues_AllHomes 	 0.0 %
# ZHVI_2bedroom 	 0.0 %
# ZHVI_3bedroom 	 0.0 %
# ZHVI_4bedroom 	 0.0 %
# ZHVI_AllHomes 	 0.0 %
# ZHVI_BottomTier 	 0.0 %
# ZHVI_MiddleTier 	 0.0 %
# ZHVI_SingleFamilyResidence 	 0.0 %
# ZHVI_TopTier 	 0.0 %
# ZRI_AllHomes 	 0.0 %
# ZRI_AllHomesPlusMultifamily 	 0.0 %
# Zri_SingleFamilyResidenceRental 	 0.0 %
