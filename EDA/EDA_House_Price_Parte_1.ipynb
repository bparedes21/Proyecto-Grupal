# %%
# Importamos librerías necesarias
import pandas as pd
import numpy as np
import os
import glob

# %%
from funcionesEDA import *

# %%
csv_files = glob.glob('*.csv')
lista_data_csv = []
  
# Creamos un bucle que recorre cada archivo csv de la carpeta, crea un df y lo agrega a una lista
for filename in csv_files:
    data = pd.read_csv(filename, encoding='utf-8')
    lista_data_csv.append(data)

# %%
# Diccionario que contiene cada df y le asigna como key el nombre del archivo correspondiente
dicc_df = {'City_MedianRentalPrice_1Bedroom':lista_data_csv[0], 'City_MedianRentalPrice_2Bedroom':lista_data_csv[1],
           'City_MedianRentalPrice_3Bedroom':lista_data_csv[2],'City_MedianRentalPrice_4Bedroom':lista_data_csv[3],
           'City_MedianRentalPrice_5Bedroom':lista_data_csv[4],'City_MedianRentalPrice_AllHomes':lista_data_csv[5],
           'City_MedianRentalPrice_Sfr':lista_data_csv[6],'City_MedianRentalPrice_Studio':lista_data_csv[7]}

# %%
for key in dicc_df:
    print(key,'\n\n',dicc_df[key].head(5),'\n\n')
# Out:
# City_MedianRentalPrice_1Bedroom
#
#     Unnamed: 0   RegionName State                             Metro  \
# 0           0     New York    NY       New York-Newark-Jersey City
# 1           1  Los Angeles    CA    Los Angeles-Long Beach-Anaheim
# 2           2      Houston    TX  Houston-The Woodlands-Sugar Land
# 3           3      Chicago    IL          Chicago-Naperville-Elgin
# 4           4  San Antonio    TX         San Antonio-New Braunfels
#
#            CountyName  SizeRank  2010-02  2010-03  2010-04  2010-05  ...  \
# 0       Queens County         1      NaN      NaN      NaN   2250.0  ...
# 1  Los Angeles County         2      NaN      NaN      NaN      NaN  ...
# 2       Harris County         3      NaN      NaN      NaN      NaN  ...
# 3         Cook County         4      NaN      NaN      NaN      NaN  ...
# 4        Bexar County         5      NaN      NaN      NaN      NaN  ...
#
#    2019-03  2019-04  2019-05  2019-06  2019-07  2019-08  2019-09  2019-10  \
# ...

# %%
for key in dicc_df:
    print(key,'\n\n',dicc_df[key].info(),'\n\n')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 818 entries, 0 to 817
# Columns: 125 entries, Unnamed: 0 to 2019-12
# dtypes: float64(119), int64(2), object(4)
# memory usage: 799.0+ KB
# City_MedianRentalPrice_1Bedroom
#
#  None
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1265 entries, 0 to 1264
# Columns: 125 entries, Unnamed: 0 to 2019-12
# dtypes: float64(119), int64(2), object(4)
# memory usage: 1.2+ MB
# City_MedianRentalPrice_2Bedroom
#
#  None
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990 entries, 0 to 989
# Columns: 125 entries, Unnamed: 0 to 2019-12
# dtypes: float64(119), int64(2), object(4)
# memory usage: 966.9+ KB
# City_MedianRentalPrice_3Bedroom
#
#  None
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 316 entries, 0 to 315
# Columns: 125 entries, Unnamed: 0 to 2019-12
# dtypes: float64(119), int64(2), object(4)
# memory usage: 308.7+ KB
# City_MedianRentalPrice_4Bedroom
#
#  None
#
#
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
for key in dicc_df:
    print(key,'\n\n',dicc_df[key].describe(exclude=np.number),'\n\n')
# Out:
# City_MedianRentalPrice_1Bedroom
#
#           RegionName State                                  Metro  \
# count           818   818                                    818
# unique          773    51                                    196
# top     Springfield    CA  Miami-Fort Lauderdale-West Palm Beach
# freq              3   127                                     51
#
#            CountyName
# count             818
# unique            294
# top     Orange County
# freq               25
#
#
# City_MedianRentalPrice_2Bedroom
#
#           RegionName State                                  Metro  \
# count          1265  1265                                   1265
# unique         1177    51                                    288
# top     Springfield    CA  Miami-Fort Lauderdale-West Palm Beach
# freq              5   199                                     69
#
#                 CountyName
# count                 1265
# unique                 414
# top     Los Angeles County
# ...

# %%
for key in dicc_df:
    print(key,'\n\n',dicc_df[key].describe(exclude=object),'\n\n')
# Out:
# City_MedianRentalPrice_1Bedroom
#
#         Unnamed: 0    SizeRank      2010-02      2010-03      2010-04  \
# count  818.000000  818.000000     3.000000     3.000000     3.000000
# mean   408.500000  409.498778  1521.666667  1463.333333  1491.666667
# std    236.280554  236.280942   402.657837   338.427737   341.259920
# min      0.000000    1.000000  1095.000000  1090.000000  1125.000000
# 25%    204.250000  205.250000  1335.000000  1320.000000  1337.500000
# 50%    408.500000  409.500000  1575.000000  1550.000000  1550.000000
# 75%    612.750000  613.750000  1735.000000  1650.000000  1675.000000
# max    817.000000  818.000000  1895.000000  1750.000000  1800.000000
#
#            2010-05      2010-06      2010-07      2010-08      2010-09  ...  \
# count     4.000000     4.000000     4.000000     4.000000     8.000000  ...
# mean   1643.750000  1692.250000  1625.000000  1606.250000  1441.250000  ...
# std     469.208109   495.755568   472.140516   538.371387   670.835034  ...
# ...

# %% [markdown]
# ## - Valores Nulos

# %%
valores_faltantes(dicc_df)
# Out:
# City_MedianRentalPrice_1Bedroom
#
# Unnamed: 0 	 0.0 %
# RegionName 	 0.0 %
# State 	 0.0 %
# Metro 	 0.0 %
# CountyName 	 0.0 %
# SizeRank 	 0.0 %
# 2010-02 	 99.63 %
# 2010-03 	 99.63 %
# 2010-04 	 99.63 %
# 2010-05 	 99.51 %
# 2010-06 	 99.51 %
# 2010-07 	 99.51 %
# 2010-08 	 99.51 %
# 2010-09 	 99.02 %
# 2010-10 	 98.53 %
# 2010-11 	 98.41 %
# 2010-12 	 98.41 %
# 2011-01 	 97.07 %
# 2011-02 	 94.62 %
# 2011-03 	 94.62 %
# 2011-04 	 94.38 %
# 2011-05 	 94.01 %
# 2011-06 	 93.03 %
# 2011-07 	 92.05 %
# 2011-08 	 91.44 %
# 2011-09 	 90.34 %
# 2011-10 	 89.12 %
# 2011-11 	 87.9 %
# 2011-12 	 87.29 %
# 2012-01 	 86.55 %
# 2012-02 	 86.19 %
# 2012-03 	 85.82 %
# 2012-04 	 85.82 %
# 2012-05 	 85.57 %
# 2012-06 	 85.33 %
# 2012-07 	 84.84 %
# 2012-08 	 84.47 %
# 2012-09 	 84.35 %
# 2012-10 	 84.23 %
# 2012-11 	 83.99 %
# 2012-12 	 83.99 %
# 2013-01 	 83.99 %
# 2013-02 	 83.62 %
# 2013-03 	 83.62 %
# 2013-04 	 83.62 %
# 2013-05 	 83.5 %
# 2013-06 	 83.37 %
# 2013-07 	 83.37 %
# ...

# %% [markdown]
# ## -- Registros Duplicados

# %%
registros_duplicados(dicc_df)
# Out:
# City_MedianRentalPrice_1Bedroom : 0
# City_MedianRentalPrice_2Bedroom : 0
# City_MedianRentalPrice_3Bedroom : 0
# City_MedianRentalPrice_4Bedroom : 0
# City_MedianRentalPrice_5Bedroom : 0
# City_MedianRentalPrice_AllHomes : 0
# City_MedianRentalPrice_Sfr : 0
# City_MedianRentalPrice_Studio : 0

# %% [markdown]
# ## -- Outliers

# %%
cantidad_outliers(dicc_df)
# Out:
# City_MedianRentalPrice_1Bedroom
# 2010-07
# Q1:  1406.25
# Q3:  1718.75
# IQR:  312.5
# BI:  937.5
# BS:  2187.5
# Hay 1 valores atípicos en la variable 2010-07
#
#
# City_MedianRentalPrice_1Bedroom
# 2010-08
# Q1:  1381.25
# Q3:  1731.25
# IQR:  350.0
# BI:  856.25
# BS:  2256.25
# Hay 1 valores atípicos en la variable 2010-08
#
#
# City_MedianRentalPrice_1Bedroom
# 2010-10
# Q1:  1221.875
# Q3:  1649.0
# IQR:  427.125
# BI:  581.1875
# BS:  2289.6875
# Hay 2 valores atípicos en la variable 2010-10
#
#
# City_MedianRentalPrice_1Bedroom
# 2010-11
# Q1:  1100.0
# Q3:  1611.5
# IQR:  511.5
# BI:  332.75
# BS:  2378.75
# Hay 1 valores atípicos en la variable 2010-11
#
#
# City_MedianRentalPrice_1Bedroom
# 2011-02
# Q1:  850.0
# Q3:  1386.75
# IQR:  536.75
# BI:  44.875
# BS:  2191.875
# Hay 1 valores atípicos en la variable 2011-02
#
#
# City_MedianRentalPrice_1Bedroom
# 2011-03
# Q1:  853.75
# Q3:  1387.5
# IQR:  533.75
# BI:  53.125
# BS:  2188.125
# ...
