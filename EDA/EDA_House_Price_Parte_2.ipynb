# %%
# Importamos librerías necesarias
import pandas as pd
import numpy as np
import os
import glob

# %%
from funcionesEDA import *

# %%
csv_files = glob.glob('*.csv')
lista_data_csv = []
  
# Creamos un bucle que recorre cada archivo csv de la carpeta, crea un df y lo agrega a una lista
for filename in csv_files:
    data = pd.read_csv(filename, encoding='utf-8')
    lista_data_csv.append(data)

# %%
# Diccionario que contiene cada df y le asigna como key el nombre del archivo correspondiente
dicc_df = {'City_Zhvi_1Bedroom':lista_data_csv[0], 'City_Zhvi_2Bedroom':lista_data_csv[1],
           'City_Zhvi_3Bedroom':lista_data_csv[2],'City_Zhvi_4Bedroom':lista_data_csv[3],
           'City_Zhvi_5Bedroom':lista_data_csv[4],'City_Zhvi_AllHomes':lista_data_csv[5],
           'City_Zhvi_Condominum':lista_data_csv[6],'City_Zhvi_SingleFamilyResidence':lista_data_csv[7]}

# %%
for key in dicc_df:
    print(key,'\n\n',dicc_df[key].head(5),'\n\n')
# Out:
# City_Zhvi_1Bedroom
#
#     Unnamed: 0  RegionID  SizeRank   RegionName RegionType StateName State  \
# 0           0      6181         0     New York       City        NY    NY
# 1           1     12447         1  Los Angeles       City        CA    CA
# 2           2     39051         2      Houston       City        TX    TX
# 3           3     17426         3      Chicago       City        IL    IL
# 4           4      6915         4  San Antonio       City        TX    TX
#
#                               Metro          CountyName  1996-01-31  ...  \
# 0       New York-Newark-Jersey City       Queens County    139028.0  ...
# 1    Los Angeles-Long Beach-Anaheim  Los Angeles County    114152.0  ...
# 2  Houston-The Woodlands-Sugar Land       Harris County     68246.0  ...
# 3          Chicago-Naperville-Elgin         Cook County     95803.0  ...
# 4         San Antonio-New Braunfels        Bexar County     55420.0  ...
#
# ...

# %%
for key in dicc_df:
    print(key,'\n\n',dicc_df[key].info(),'\n\n')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14927 entries, 0 to 14926
# Columns: 300 entries, Unnamed: 0 to 2020-03-31
# dtypes: float64(291), int64(3), object(6)
# memory usage: 34.2+ MB
# City_Zhvi_1Bedroom
#
#  None
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23396 entries, 0 to 23395
# Columns: 300 entries, Unnamed: 0 to 2020-03-31
# dtypes: float64(291), int64(3), object(6)
# memory usage: 53.5+ MB
# City_Zhvi_2Bedroom
#
#  None
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25735 entries, 0 to 25734
# Columns: 300 entries, Unnamed: 0 to 2020-03-31
# dtypes: float64(291), int64(3), object(6)
# memory usage: 58.9+ MB
# City_Zhvi_3Bedroom
#
#  None
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23463 entries, 0 to 23462
# Columns: 300 entries, Unnamed: 0 to 2020-03-31
# dtypes: float64(291), int64(3), object(6)
# memory usage: 53.7+ MB
# City_Zhvi_4Bedroom
#
#  None
#
#
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
for key in dicc_df:
    print(key,'\n\n',dicc_df[key].describe(exclude=np.number),'\n\n')
# Out:
# City_Zhvi_1Bedroom
#
#         RegionName RegionType StateName  State                        Metro  \
# count       14927      14927     14927  14927                        11852
# unique      10486          1        51     51                          832
# top       Clinton       City        NY     NY  New York-Newark-Jersey City
# freq           21      14927       867    867                          429
#
#                CountyName
# count               14927
# unique               1554
# top     Washington County
# freq                  174
#
#
# City_Zhvi_2Bedroom
#
#         RegionName RegionType StateName  State                        Metro  \
# count       23396      23396     23396  23396                        17834
# unique      15388          1        51     51                          859
# top      Franklin       City        PA     PA  New York-Newark-Jersey City
# freq           26      23396      1573   1573                          562
#
#                CountyName
# ...

# %%
for key in dicc_df:
    print(key,'\n\n',dicc_df[key].describe(exclude=object),'\n\n')
# Out:
# City_Zhvi_1Bedroom
#
#           Unnamed: 0       RegionID      SizeRank     1996-01-31  \
# count  14927.000000   14927.000000  14927.000000    3052.000000
# mean    7463.000000   62002.395190  11023.768138   97987.753277
# std     4309.198069  101334.575419   8045.487947   59082.286851
# min        0.000000    3304.000000      0.000000   10996.000000
# 25%     3731.500000   17767.500000   4197.000000   59337.250000
# 50%     7463.000000   32695.000000   9407.000000   86884.000000
# 75%    11194.500000   47988.000000  16692.500000  122122.250000
# max    14926.000000  737791.000000  29449.000000  689827.000000
#
#           1996-02-29     1996-03-31     1996-04-30     1996-05-31  \
# count    3214.000000    3263.000000    3280.000000    3304.000000
# mean    97487.608276   97120.899479   97028.637805   97117.967918
# std     58815.704695   58597.929936   58479.295995   58474.367174
# min     10946.000000   10945.000000   10925.000000   10993.000000
# ...

# %% [markdown]
# ## - Valores Nulos

# %%
valores_faltantes(dicc_df)
# Out:
# City_Zhvi_1Bedroom
#
# Unnamed: 0 	 0.0 %
# RegionID 	 0.0 %
# SizeRank 	 0.0 %
# RegionName 	 0.0 %
# RegionType 	 0.0 %
# StateName 	 0.0 %
# State 	 0.0 %
# Metro 	 20.6 %
# CountyName 	 0.0 %
# 1996-01-31 	 79.55 %
# 1996-02-29 	 78.47 %
# 1996-03-31 	 78.14 %
# 1996-04-30 	 78.03 %
# 1996-05-31 	 77.87 %
# 1996-06-30 	 77.77 %
# 1996-07-31 	 77.72 %
# 1996-08-31 	 77.64 %
# 1996-09-30 	 77.61 %
# 1996-10-31 	 77.55 %
# 1996-11-30 	 77.44 %
# 1996-12-31 	 77.33 %
# 1997-01-31 	 77.11 %
# 1997-02-28 	 76.97 %
# 1997-03-31 	 76.79 %
# 1997-04-30 	 76.71 %
# 1997-05-31 	 76.58 %
# 1997-06-30 	 76.52 %
# 1997-07-31 	 76.39 %
# 1997-08-31 	 76.28 %
# 1997-09-30 	 76.22 %
# 1997-10-31 	 76.1 %
# 1997-11-30 	 75.95 %
# 1997-12-31 	 75.86 %
# 1998-01-31 	 75.71 %
# 1998-02-28 	 75.58 %
# 1998-03-31 	 75.43 %
# 1998-04-30 	 75.17 %
# 1998-05-31 	 74.93 %
# 1998-06-30 	 74.79 %
# 1998-07-31 	 74.66 %
# 1998-08-31 	 74.48 %
# 1998-09-30 	 74.21 %
# 1998-10-31 	 74.02 %
# ...

# %% [markdown]
# ## -- Registros Duplicados

# %%
registros_duplicados(dicc_df)
# Out:
# City_Zhvi_1Bedroom : 0
# City_Zhvi_2Bedroom : 0
# City_Zhvi_3Bedroom : 0
# City_Zhvi_4Bedroom : 0
# City_Zhvi_5Bedroom : 0
# City_Zhvi_AllHomes : 0
# City_Zhvi_Condominum : 0
# City_Zhvi_SingleFamilyResidence : 0

# %% [markdown]
# ## -- Outliers

# %%
cantidad_outliers(dicc_df)
# Out:
# City_Zhvi_1Bedroom
# Unnamed: 0
# Q1:  3731.5
# Q3:  11194.5
# IQR:  7463.0
# BI:  -7463.0
# BS:  22389.0
# Hay 0 valores atípicos en la variable Unnamed: 0
#
#
# City_Zhvi_1Bedroom
# RegionID
# Q1:  17767.5
# Q3:  47988.0
# IQR:  30220.5
# BI:  -27563.25
# BS:  93318.75
# Hay 1549 valores atípicos en la variable RegionID
#
#
# City_Zhvi_1Bedroom
# SizeRank
# Q1:  4197.0
# Q3:  16692.5
# IQR:  12495.5
# BI:  -14546.25
# BS:  35435.75
# Hay 0 valores atípicos en la variable SizeRank
#
#
# City_Zhvi_1Bedroom
# 1996-01-31
# Q1:  59337.25
# Q3:  122122.25
# IQR:  62785.0
# BI:  -34840.25
# BS:  216299.75
# Hay 118 valores atípicos en la variable 1996-01-31
#
#
# City_Zhvi_1Bedroom
# 1996-02-29
# Q1:  58684.25
# Q3:  121588.5
# IQR:  62904.25
# BI:  -35672.125
# BS:  215944.875
# Hay 124 valores atípicos en la variable 1996-02-29
#
#
# City_Zhvi_1Bedroom
# 1996-03-31
# Q1:  58406.5
# Q3:  121406.0
# IQR:  62999.5
# BI:  -36092.75
# BS:  215905.25
# ...
